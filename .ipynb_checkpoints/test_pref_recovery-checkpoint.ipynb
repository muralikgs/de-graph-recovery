# %%
import numpy as np 
from matplotlib import pyplot as plt 
import scipy.io as sio

from utils import *
from generateData import generateSynthData
from src.data import datagen as dg
from src.measurements import *
from src.covarianceRecovery import *
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In [1], line 6
#       3 import scipy.io as sio
#       5 from utils import *
# ----> 6 from generateData import generateSynthData
#       7 from src.data import datagen as dg
#       8 from src.measurements import *
#
# File /storage/coda1/p-ff14/0/msethuraman7/projects_murali/de-graph-recovery/generateData.py:5
#       3 import networkx as nx
#       4 from tqdm import tqdm
# ----> 5 import igraph as ig
#       6 from scipy.linalg import expm
#       8 # generates synthetic graphs sampled from Erdos-Renyi model
#
# ModuleNotFoundError: No module named 'igraph'

# %%
n_nodes=100
data_gen = dg.Dataset(n_nodes=n_nodes, 
                      expected_density=1,
                      n_samples=5000,
                      n_experiments=5,
                      min_targets=5,
                      max_targets=5,
                      mode='no-constraint')
datasets = data_gen.generate()
intervention_sets = data_gen.targets

# %%
observed_set = np.setdiff1d(np.arange(n_nodes), intervention_sets[0])
U = np.zeros((n_nodes, n_nodes))
U[observed_set, observed_set] = 1

W = data_gen.gen_model.weights
Cov_X = np.linalg.inv(np.eye(n_nodes) - U@W.T) @ np.linalg.inv(np.eye(n_nodes) - U@W.T).T

# %%
indices = np.concatenate((intervention_sets[0], observed_set))
col_ind_r, row_ind_r = np.meshgrid(indices, indices)

Cov_X_r = Cov_X[row_ind_r, col_ind_r]

# %%
# %matplotlib widget

plt.imshow(Cov_X_r[:15, :15])
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
lambda_h = sio.loadmat("lambda_h_2.mat")['lambda_h']
lambda_l = sio.loadmat("lambda_l_2.mat")["lambda_l"]

A = getSensingMatrixUP(lambda_h, lambda_l, dch=10, dcl=10, nh=25, nl=75, A=1.0)
A_bs = generateA(A.shape[0], A.shape[1], delta=4)
print("Sensing matrix shape: {}".format(A.shape))

# %matplotlib widget

fig, axs = plt.subplots(2, 1)

im = axs[0].imshow(A, cmap='bwr', vmin=-1, vmax=1)
axs[0].set_title("DE Sensing Matrix")
im = axs[1].imshow(A_bs, cmap='bwr', vmin=-1, vmax=1)
axs[1].set_title("Baseline Sensing Matrix")
# cbar = plt.colorbar(im)
# Out:
# Sensing matrix shape: (35, 100)
# Text(0.5, 1.0, 'Baseline Sensing Matrix')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
nl = 75
nh = 25

X = datasets[0]
Y = makeIntMeasurements(A, X, intervention_sets[0])
Y_bs = makeIntMeasurements(A_bs, X, intervention_sets[0])

Sig_Y = (1/Y.shape[0]) * Y.T @ Y
Sig_Y_bs = (1/Y_bs.shape[0]) * Y_bs.T @ Y_bs

# %%
Cov_X_de_r = covarianceEstimateTorch(A, Sig_Y, pen_coeff=0.5)
Cov_X_bs_r = covarianceEstimateTorch(A_bs, Sig_Y_bs, pen_coeff=0.5)

# %%
Cov_X_hh = Cov_X_r[:5, 5:nh]
Cov_x_hat_de_hh = Cov_X_de_r[:5, 5:nh]
Cov_x_hat_bs_hh = Cov_X_bs_r[:5, 5:nh]

# %%
print("DE Error, Fro: {}, MAE: {}".format(np.linalg.norm(Cov_X_hh - Cov_x_hat_de_hh, 'fro'), np.abs(Cov_X_hh - Cov_x_hat_de_hh).max()))
print("BS Error, Fro: {}, MAE: {}".format(np.linalg.norm(Cov_X_hh - Cov_x_hat_bs_hh, 'fro'), np.abs(Cov_X_hh - Cov_x_hat_bs_hh).max()))
# Out:
# DE Error, Fro: 0.12152081818201188, MAE: 0.0709653754423216
# BS Error, Fro: 0.43052469060257437, MAE: 0.33203431991687765

# %%
S_x = (1/nSamples) * X.T @ X 
S_x_hh = S_x[:nh, :nh]

print(np.linalg.norm(Cov_X_hh - S_x_hh, 'fro'))
# Out:
# 0.7967294532978965
